# %%
# What data type is each of the following (evaluate where necessary)?

#Answer

# 5 - int(integer)
# 5.0 - float
# 5 > 1 - Boolean (evaluates to True)
# '5' - str(string)
# 5 * 2 - int (evaluates to 10)
# '5' * 2 - str (evaluates to 55)
# '5' + '2' - str(evaluates to 52)
# 5 / 2 - float(evaluates to 2.5)
# 5 % 2 - int(evaluates to 1)
# {5, 2, 1} -set
# 5 == 3 -boolean(evaluates to False)
# Pi (the number) - float

# %%
#Write (and evaluate) python expressions that answer these questions:

#a. How many letters are there in 'Supercalifragilisticexpialidocious'?
   #Answer for a
word = "Supercalifragilisticexpialidocious"
number_of_letter = len(word)
number_of_letter

#b. Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?
    #Answer b
    #Yes,'Supercalifragilisticexpialidocious' does contain 'ice' as a substring: True.

#c. Which of the following words is the longest:
#Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or
#Bababadalgharaghtakamminarronnkonn?
 
    # Answer c
    #'Supercalifragilisticexpialidocious' and 'Bababadalgharaghtakamminarronnkonn' is the longest word.


#d. Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian',
#'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'. Which one comes last?

    #Answer d
   # In the dictionary, the composer that comes first is 'Bartok', and the one that comes last is 'Buxtehude'

# %%
#Implement function triangleArea(a,b,c) that takes as input the lengths of the 3
#sides of a triangle and returns the area of the triangle. By Heron's formula, the area
#of a triangle with side lengths a, b, and c is
#s(s - a)(s -b)(s -c)
#, where
#s = (a+b+c)/2.
#>>> triangleArea(2,2,2)
#1.7320508075688772

import math

def triangleArea(a, b, c):

    s = (a + b + c) / 2

    area = math.sqrt(s * (s - a) * (s - b) * (s - c))
    return area


result = triangleArea(2, 2, 2)
print(result)
# Out:
# 1.7320508075688772

# %%
#Write a program in python to separate odd and even integers in separate arrays. Go
#to the editor
#Test Data :
#Input the number of elements to be stored in the array :5
#Input 5 elements in the array :
#element - 0 : 25
#element - 1 : 47
#element - 2 : 42
#element - 3 : 56
#element - 4 : 32
#Expected Output:
#The Even elements are:
#42 56 32
#The Odd elements are :
#25 47


def separate_odd_even(elements):
    odd_numbers = []
    even_numbers = []
    
    for num in elements:
        if num % 2 == 0:
            even_numbers.append(num)
        else:
            odd_numbers.append(num)
    
    return even_numbers, odd_numbers


def main():
   
    n = int(input("Input the number of elements to be stored in the array: "))
    
    
    elements = []
    for i in range(n):
        element = int(input(f"element - {i} : "))
        elements.append(element)
    
    
    even_numbers, odd_numbers = separate_odd_even(elements)
    
    
    print("The Even elements are:")
    print(" ".join(map(str, even_numbers)))
    
    print("The Odd elements are:")
    print(" ".join(map(str, odd_numbers)))


if __name__ == "__main__":
    main()
# Out:
# Input the number of elements to be stored in the array: 5
# element - 0 : 25
# element - 1 : 47
# element - 2 : 42
# element - 3 : 56
# element - 4 : 32
# The Even elements are:
# 42 56 32
# The Odd elements are:
# 25 47

# %%
#a. Write a function inside(x,y,x1,y1,x2,y2) that returns True or False
#depending on whether the point (x,y) lies in the rectangle with lower left
#corner (x1,y1) and upper right corner (x2,y2).
#>>> inside(1,1,0,0,2,3)
#True
#>>> inside(-1,-1,0,0,2,3)
#False
#b. Use function inside() from part a. to write an expression that tests whether
#the point (1,1) lies in both of the following rectangles: one with lower left
#corner (0.3, 0.5) and upper right corner (1.1, 0.7) and the other with lower
#left corner (0.5, 0.2) and upper right corner (1.1, 2). 

#Answer A

def inside(x, y, x1, y1, x2, y2):
   
    return x1 <= x <= x2 and y1 <= y <= y2


print(inside(1, 1, 0, 0, 2, 3))  
print(inside(-1, -1, 0, 0, 2, 3))  


#Answer B


rect1 = inside(1, 1, 0.3, 0.5, 1.1, 0.7)


rect2 = inside(1, 1, 0.5, 0.2, 1.1, 2)


both_inside = rect1 and rect2


print("Is the point (1, 1) inside both rectangles?", both_inside)
# Out:
# True
# False
# Is the point (1, 1) inside both rectangles? False

# %%
#You can turn a word into pig-Latin using the following two rules (simplified):
#• If the word starts with a consonant, move that letter to the end and append
#'ay'. For example, 'happy' becomes 'appyhay' and 'pencil' becomes 'encilpay'.
#• If the word starts with a vowel, simply append 'way' to the end of the word.
#For example, 'enter' becomes 'enterway' and 'other' becomes 'otherway' . For
#our purposes, there are 5 vowels: a, e, i, o, u (so we count y as a consonant).
#Write a function pig() that takes a word (i.e., a string) as input and returns its pigLatin form. Your function should still work if the input word contains upper case
#characters. Your output should always be lower case however.
#>>> pig('happy')
#'appyhay'
#>>> pig('Enter')
#'enterway'

def pig(word):
    
    word_lower = word.lower()
    
    
    vowels = 'aeiou'
    
    
    if word_lower[0] in vowels:
        pig_latin_word = word_lower + 'way'
    else:
        pig_latin_word = word_lower[1:] + word_lower[0] + 'ay'
    
    return pig_latin_word


print(pig('happy'))  
print(pig('Enter'))
# Out:
# appyhay
# enterway

# %%
#File bloodtype1.txt records blood-types of patients (A, B, AB, O or OO) at a clinic.
#Write a function bldcount() that reads the file with name name and reports (i.e.,
#prints) how many patients there are in each bloodtype.
#>>> bldcount('bloodtype.txt')
#There are 10 patients of blood type A.
#There are 10 patients of blood type AB.
#There are 12 patients of blood type O.
#There are no patients of blood type OO.

def bldcount(filename):
    blood_types = {
        'A': 0,
        'B': 0,
        'AB': 0,
        'O': 0,
        'OO': 0
    }   
    try:
        with open(filename, 'r') as file: 
            blood_data = file.read().strip().split() 
    except FileNotFoundError:
        print(f"The file '{filename}' does not exist.")
        return  
    for blood in blood_data:
        if blood in blood_types:  
            blood_types[blood] += 1 
    for blood, count in blood_types.items():
        if count == 1:  
            print(f"There is one patient of blood type {blood}.")
        elif count == 0: 
            print(f"There are no patients of blood type {blood}.")
        else:  
            print(f"There are {count} patients of blood type {blood}.")

bldcount('bloodtype1.txt')
# Out:
# There are 15 patients of blood type A.
# There is one patient of blood type B.
# There are 13 patients of blood type AB.
# There are 15 patients of blood type O.
# There are no patients of blood type OO.

# %%
#Write a function curconv() that takes as input:
#1. a currency represented using a string (e.g., 'JPY' for the Japanese Yen or
#'EUR' for the Euro)
#2. an amount
#and then converts and returns the amount in US dollars.
#>>> curconv('EUR', 100)
#122.96544
#>>> curconv('JPY', 100)
#1.241401
#The currency rates you will need are stored in file currencies.txt:
#AUD 1.0345157 Australian Dollar
#CHF 1.0237414 Swiss Franc
#CNY 0.1550176 Chinese Yuan
#DKK 0.1651442 Danish Krone
#EUR 1.2296544 Euro
#HKD 0.1270207 Hong Kong Dollar
#INR 0.0177643 Indian Rupee
#JPY 0.01241401 Japanese Yen
#MXN 0.0751848 Mexican Peso
#MYR 0.3145411 Malaysian Ringgit
#NOK 0.1677063 Norwegian Krone
#NZD 0.8003591 New Zealand Dollar
#PHP 0.0233234 Philippine Peso
#SEK 0.148269 Swedish Krona
#SGD 0.788871 Singapore Dollar
#THB 0.0313789 Thai Baht

def curconv(currency, amount):
    rates = {}

    with open('currencies.txt', 'r') as file:
        for line in file:
            parts = line.split()
            if len(parts) >= 2:  
                code = parts[0]  
                rate = float(parts[1])  
                rates[code] = rate

    if currency in rates:
        return amount * rates[currency]
    else:
        raise ValueError("Currency not found.")

print(curconv('EUR', 100))  
print(curconv('JPY', 100))
# Out:
# 122.96544
# 1.241401

# %%
#Each of the following will cause an exception (an error). Identify what type of
#exception each will cause.

#Trying to add incompatible variables, as in
#adding 6 + ‘a’
#Answer
# Exception type: TypeError

#Referring to the 12th item of a list that has only 10
#items
#Answer
# Exception type:InderError

#Using a value that is out of range for a function’s
#input, such as calling math.sqrt(-1.0)
#Answer
# Exception type:ValueError

#Using an undeclared variable, such as print(x)
#when x has not been defined
#Answer
# Exception type:NameError

#Trying to open a file that does not exist, such as
#mistyping the file name or looking in the wrong
#directory. 
#Answer
# Exception type:FileNotFoundError

# %%
#Encryption is the process of hiding the meaning of a text by substituting letters in the
#message with other letters, according to some system. If the process is successful, no
#one but the intended recipient can understand the encrypted message. Cryptanalysis
#refers to attempts to undo the encryption, even if some details of the encryption are
#unknown (for example, if an encrypted message has been intercepted). The first step
#of cryptanalysis is often to build up a table of letter frequencies in the encrypted text.
#Assume that the string letters is already defined as
#'abcdefghijklmnopqrstuvwxyz'. Write a function called frequencies()
#that takes a string as its only parameter, and returns a list of integers, showing the
#number of times each character appears in the text. Your function may ignore any
#characters that are not in letters.
#>>> frequencies('The quick red fox got bored and went home.')
#[1, 1, 1, 3, 5, 1, 1, 2, 1, 0, 1, 0, 1, 2, 4, 0, 1, 2, 0, 2,
#1, 0, 1, 1, 0, 0]
#>>> frequencies('apple')

def frequencies(text):
    letters = 'abcdefghijklmnopqrstuvwxyz'
    frequency_count = [0] * 26  
    text = text.lower()
        for char in text:
        if char in letters:
            frequency_count[ord(char) - ord('a')] += 1
        return frequency_count

print(frequencies('The quick red fox got bored and went home.'))
print(frequencies('apple'))
# Out:
#   File "<ipython-input-10-9e9667f8857c>", line 21
#     for char in text:
#     ^
# IndentationError: unexpected indent
